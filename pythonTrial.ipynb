# %%
import sys
print(sys.executable)
# Out:
# c:\Users\USER\Desktop\CodeWaveML\Projects\.venv\Scripts\python.exe

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.(Q1 LeetCode)
#
# list=[2,7,11,15]
# target = 9

# %%
#type the answere here

# %% [markdown]
# Given an integer x, return true if x is a palindrome, and false otherwise.(Q6 Leetcode)

# %%
#type the answere here

# %% [markdown]
# C can be placed before D (500) and M (1000) to make 400 and 900.(Q13 leet code)
